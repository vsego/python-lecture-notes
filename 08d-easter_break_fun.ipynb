# %% [markdown]
# # Programming with Python
# #### Vedran Šego, [vsego.org](http://vsego.org/)
#
# ## Exercise (Easter Break Fun)

# %% [markdown]
# **Problem 1.** We want to work with some cars data. We keep the data in a list of dictionaries (a list for which each member is a dictionary). For each car we keep: model name (a string), colour (a string), maximum speed in miles (an integer), and a price (a float).
#
# Here is an example of a list with two cars in it:
# <div style="float: right;">![Jet Beetle](files/AB12_15_05.jpg)</div>
# ```python
# L = [
#     {
#         "name": "Jet Beetle",
#         "colour": "silver",
#         "speed": 140,
#         "price": 125000.00,
#     },
# ```
# <div style="float: right;">![The Panther](files/296_photo_home2_4.jpg)</div>
# ```python
#     {
#         "name": "The Panther",
#         "colour": "black",
#         "speed": 55,
#         "price": 101600.00
#     },
# ]
# ```
# Irrelevant for this problem, but the cars were not made up. These are the information sources:
# * on Jet Beetle: [Jet Beetle official site](http://www.ronpatrickstuff.com/), [Telegraph article](http://www.telegraph.co.uk/news/picturegalleries/howaboutthat/11164032/Jet-powered-VW-Beetle-that-goes-like-a-rocket.html),
# * on The Panther (successor to successful, but discontinued Python): [WaterCar](https://www.watercar.com/).

# %% [markdown]
# Write the following functions:
#
# * `clear(L)` that clears the contents of the list `L`.
#
# * `add(L)` that loads a natural number `n` and then loads data about `n` cars which it adds to `L`.
#
# * `print_data(L)` that prints the data `L` in tabular form.
#
# * `sort_data(L, key)` that sorts `L` by the field `key` (so, `sort(L, "name")` sorts the cars by their model name (a challenge: try to make it possible to sort by more than one key).
#
# * `filter(L, name, colour, speed_min, speed_max, price_min, price_max, reversed)` that returns the new list containing only the cars having the given values (its name should be equal to `name`, its colour should be equal to `colour`, etc) if `reversed` is `False` (its default value) or all that do not satisfy the conditions if `reversed=True`.
#   All paramteres except `L` should be optional and named (i.e., `filter(L, "Jet Beetle")` is not an allowed call, but `filter(L, name="Jet Beetle")` and `filter(L, speed_min=17, price_max=1E5)` are.
#   The parameters `speed_min` and `speed_max` stand for "min/max top speed", respectively; the parameters `price_min` and `price_max` stand for "min/max price", respectively.
#
# * `delete_data(L, name, colour, speed_min, speed_max, price_min, price_max, reversed)`  removes all the list elements that `filter` with the same arguments would return.
#
# * `save_data(L, filename)` saves the data from `L` to a file with the name given by `filename`.
#
# * `load_data(filename)` loads the data from a file with the name given by `filename` and returns it as a list of dictionaries.
#
# * `run()` that displays the menu with the following items:
# ```
#     1. Clear data
#     2. Add data
#     3. Print data
#     4. Delete data
#     5. Sort data
#     6. Save data
#     7. Load data
#     8. Load and append data
#     9. Quit
# ```
#   Then it waits for an input and, depending on its value, does the following:
#   * If input is 1, asks the user to confirm (yes/no question) and - if confirmed - clears the data;
#   * If input is 2, adds data to the list by invoking the `add` function;
#   * If input is 3, loads the filter values (those defined by the `filter` function) and prints the matches;
#   * If input is 4, loads the filter values (those defined by the `filter` function) and deletes the matches; if all the filters are left empty, it doesn't delete anything (this is what `clear` is for);
#   * If input is 5, offers the list of possible keys and sorts the data according to the user's pick;
#   * If input is 6, asks for a filename and saves the data;
#   * If input is 7, asks for a filename and loads the data (the old data is lost);
#   * If input is 8, same as 7, but the newly read data is appended to the old data (i.e., the old data is NOT lost);
#   * If input is 9, stops the function execution;
#   * If input is anything else, it is ignored.
#
#   After any of the above operations is performed, the menu is redisplayed and the user is again given the choice what to do.
#
# Further, write a program that simply invokes the `run` function.
#
# All the functions should handle the exceptions that may occur and raise their own in case of an error. The `run` function should capture all of the exceptions (i.e., the program should never crash).
